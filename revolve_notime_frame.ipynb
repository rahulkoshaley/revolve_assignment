# %%
class FilesPath(object): 
    customer_file = "/home/unicorp/evolve/data/starter/customers.csv"  #change file path of customer.csv
    product_file = "/home/unicorp/evolve/data/starter/products.csv"     #change file path of product.csv
    transactionFiles = "/home/unicorp/evolve/data/starter/transactions/"  #change directory till transactions
    outWriteFilePath = ""


from pyspark.sql import SparkSession
from pyspark.sql.functions import explode
from pyspark.sql.functions import flatten
from pyspark.sql.functions import udf
import datetime, time 
from pyspark.sql import Window
from  pyspark.sql.types import TimestampType
from pyspark.sql.functions import to_date,lit,count



spark = SparkSession \
    .builder \
    .appName("EVOLVE") \
    .getOrCreate()

def _to_timestamp(s):
    return datetime.datetime.strptime(s, '%Y-%m-%d %H:%M:%S.%f')

udf_to_timestamp = udf(_to_timestamp, TimestampType())

def createDfCsv(s):
    return spark.read.options(header='True', inferSchema='True').csv(s)

def createDfJson(s):
    return spark.read.options(header='True', inferSchema='True').json(s)

df1 = createDfCsv(FilesPath.customer_file)

df2 = createDfCsv(FilesPath.product_file)

df4 = createDfJson(FilesPath.transactionFiles +"*/*.json")
    

def _to_timestamp(s):
    return datetime.datetime.strptime(s, '%Y-%m-%d %H:%M:%S.%f')

udf_to_timestamp = udf(_to_timestamp, TimestampType())
w = Window.partitionBy('product_id')

df5 = df4.select('date_of_purchase','basket','customer_id').withColumn("date_of_purchase", udf_to_timestamp("date_of_purchase"))


df6= df5.select(df5.date_of_purchase ,df5.customer_id,explode(df5.basket.product_id).alias("product_id"))



FinalWriteDF = df1.join(df6, df1.customer_id == df6.customer_id).join(df2, df2.product_id==df6.product_id).select(lit(df1["loyalty_score"]),df6["*"],df2['product_category']).select('customer_id', lit('loyalty_score'), 'date_of_purchase', 'product_category','product_id' ,count('product_id').over(w).alias('product_count')).sort('customer_id').drop('date_of_purchase').dropDuplicates()#.show(truncate=False)
FinalWriteDF.printSchema()



FinalWriteDF.show(600)
FinalWriteDF.write.csv('finalDataCsvWithoutTimeFrame.csv')
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- loyalty_score: string (nullable = false)
#  |-- product_category: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- product_count: long (nullable = false)
#
# +-----------+-------------+----------------+----------+-------------+
# |customer_id|loyalty_score|product_category|product_id|product_count|
# +-----------+-------------+----------------+----------+-------------+
# |        C68|loyalty_score|             bws|       P62|          146|
# |       C104|loyalty_score|             bws|       P62|          146|
# |       C115|loyalty_score|             bws|       P62|          146|
# |        C20|loyalty_score|             bws|       P62|          146|
# |        C31|loyalty_score|             bws|       P62|          146|
# |        C38|loyalty_score|             bws|       P62|          146|
# |        C60|loyalty_score|             bws|       P62|          146|
# |       C110|loyalty_score|             bws|       P62|          146|
# |       C111|loyalty_score|             bws|       P62|          146|
# |        C61|loyalty_score|             bws|       P62|          146|
# |        C88|loyalty_score|             bws|       P62|          146|
# |        C92|loyalty_score|             bws|       P62|          146|
# |       C136|loyalty_score|             bws|       P62|          146|
# |         C1|loyalty_score|             bws|       P62|          146|
# |        C18|loyalty_score|             bws|       P62|          146|
# |        C55|loyalty_score|             bws|       P62|          146|
# |       C116|loyalty_score|             bws|       P62|          146|
# |        C32|loyalty_score|             bws|       P62|          146|
# |        C23|loyalty_score|             bws|       P62|          146|
# |       C101|loyalty_score|             bws|       P62|          146|
# |        C97|loyalty_score|             bws|       P62|          146|
# |        C49|loyalty_score|             bws|       P62|          146|
# |        C98|loyalty_score|             bws|       P62|          146|
# |         C4|loyalty_score|             bws|       P62|          146|
# |        C95|loyalty_score|             bws|       P62|          146|
# |        C91|loyalty_score|             bws|       P62|          146|
# |       C109|loyalty_score|             bws|       P62|          146|
# |       C120|loyalty_score|             bws|       P62|          146|
# |       C105|loyalty_score|             bws|       P62|          146|
# |       C108|loyalty_score|             bws|       P62|          146|
# |       C134|loyalty_score|             bws|       P62|          146|
# |        C26|loyalty_score|             bws|       P62|          146|
# |        C45|loyalty_score|             bws|       P62|          146|
# |        C34|loyalty_score|         clothes|       P13|           22|
# |        C52|loyalty_score|         clothes|       P13|           22|
# |         C5|loyalty_score|         clothes|       P13|           22|
# |       C105|loyalty_score|         clothes|       P13|           22|
# |        C71|loyalty_score|         clothes|       P13|           22|
# |        C87|loyalty_score|         clothes|       P13|           22|
# |        C25|loyalty_score|         clothes|       P13|           22|
# |       C117|loyalty_score|         clothes|       P13|           22|
# |       C128|loyalty_score|         clothes|       P13|           22|
# |        C35|loyalty_score|         clothes|       P13|           22|
# |        C21|loyalty_score|         clothes|       P13|           22|
# |        C65|loyalty_score|            food|       P59|           54|
# |       C123|loyalty_score|            food|       P59|           54|
# |        C16|loyalty_score|            food|       P59|           54|
# |        C12|loyalty_score|            food|       P59|           54|
# |        C54|loyalty_score|            food|       P59|           54|
# |         C8|loyalty_score|            food|       P59|           54|
# |        C11|loyalty_score|            food|       P59|           54|
# |        C73|loyalty_score|            food|       P59|           54|
# |         C7|loyalty_score|            food|       P59|           54|
# |        C62|loyalty_score|            food|       P59|           54|
# |       C101|loyalty_score|            food|       P59|           54|
# |        C47|loyalty_score|            food|       P59|           54|
# |       C107|loyalty_score|            food|       P59|           54|
# |       C100|loyalty_score|            food|       P59|           54|
# |         C6|loyalty_score|            food|       P59|           54|
# |        C10|loyalty_score|            food|       P59|           54|
# |        C28|loyalty_score|            food|       P59|           54|
# |       C110|loyalty_score|            food|       P59|           54|
# |        C41|loyalty_score|            food|       P59|           54|
# |       C112|loyalty_score|            food|       P59|           54|
# |       C120|loyalty_score|            food|       P59|           54|
# |       C125|loyalty_score|            food|       P59|           54|
# |        C66|loyalty_score|            food|       P59|           54|
# |        C67|loyalty_score|            food|       P59|           54|
# |       C119|loyalty_score|            food|       P59|           54|
# |        C42|loyalty_score|            food|       P59|           54|
# |        C83|loyalty_score|            food|       P59|           54|
# |        C95|loyalty_score|            food|       P59|           54|
# |        C80|loyalty_score|            food|       P59|           54|
# |       C113|loyalty_score|            food|       P59|           54|
# |        C21|loyalty_score|            food|       P59|           54|
# |        C30|loyalty_score|            food|       P59|           54|
# |        C53|loyalty_score|            food|       P59|           54|
# |        C52|loyalty_score|            food|       P59|           54|
# |        C78|loyalty_score|            food|       P59|           54|
# |        C63|loyalty_score|            food|       P59|           54|
# |       C128|loyalty_score|            food|       P59|           54|
# |         C2|loyalty_score|       fruit_veg|       P30|           64|
# |        C38|loyalty_score|       fruit_veg|       P30|           64|
# |        C48|loyalty_score|       fruit_veg|       P30|           64|
# |       C123|loyalty_score|       fruit_veg|       P30|           64|
# |       C132|loyalty_score|       fruit_veg|       P30|           64|
# |        C70|loyalty_score|       fruit_veg|       P30|           64|
# |       C127|loyalty_score|       fruit_veg|       P30|           64|
# |        C53|loyalty_score|       fruit_veg|       P30|           64|
# |        C55|loyalty_score|       fruit_veg|       P30|           64|
# |        C56|loyalty_score|       fruit_veg|       P30|           64|
# |        C32|loyalty_score|       fruit_veg|       P30|           64|
# |        C92|loyalty_score|       fruit_veg|       P30|           64|
# |       C117|loyalty_score|       fruit_veg|       P30|           64|
# |        C29|loyalty_score|       fruit_veg|       P30|           64|
# |       C116|loyalty_score|       fruit_veg|       P30|           64|
# |        C77|loyalty_score|       fruit_veg|       P30|           64|
# |        C90|loyalty_score|       fruit_veg|       P30|           64|
# |        C28|loyalty_score|       fruit_veg|       P30|           64|
# |        C97|loyalty_score|       fruit_veg|       P30|           64|
# |        C65|loyalty_score|       fruit_veg|       P30|           64|
# |        C39|loyalty_score|       fruit_veg|       P30|           64|
# |       C102|loyalty_score|       fruit_veg|       P30|           64|
# |        C37|loyalty_score|       fruit_veg|       P30|           64|
# |        C93|loyalty_score|       fruit_veg|       P30|           64|
# |       C126|loyalty_score|       fruit_veg|       P30|           64|
# |        C64|loyalty_score|       fruit_veg|       P30|           64|
# |        C57|loyalty_score|       fruit_veg|       P30|           64|
# |       C121|loyalty_score|       fruit_veg|       P30|           64|
# |       C133|loyalty_score|       fruit_veg|       P30|           64|
# |       C106|loyalty_score|       fruit_veg|       P30|           64|
# |       C109|loyalty_score|       fruit_veg|       P30|           64|
# |        C36|loyalty_score|       fruit_veg|       P30|           64|
# |        C52|loyalty_score|       fruit_veg|       P30|           64|
# |        C45|loyalty_score|       fruit_veg|       P30|           64|
# |        C95|loyalty_score|       fruit_veg|       P30|           64|
# |       C134|loyalty_score|       fruit_veg|       P30|           64|
# |       C108|loyalty_score|       fruit_veg|       P30|           64|
# |        C23|loyalty_score|       fruit_veg|       P30|           64|
# |        C23|loyalty_score|       fruit_veg|       P23|           64|
# |       C104|loyalty_score|       fruit_veg|       P23|           64|
# |        C27|loyalty_score|       fruit_veg|       P23|           64|
# |       C131|loyalty_score|       fruit_veg|       P23|           64|
# |        C38|loyalty_score|       fruit_veg|       P23|           64|
# |       C107|loyalty_score|       fruit_veg|       P23|           64|
# |        C77|loyalty_score|       fruit_veg|       P23|           64|
# |        C67|loyalty_score|       fruit_veg|       P23|           64|
# |        C93|loyalty_score|       fruit_veg|       P23|           64|
# |        C95|loyalty_score|       fruit_veg|       P23|           64|
# |       C110|loyalty_score|       fruit_veg|       P23|           64|
# |        C32|loyalty_score|       fruit_veg|       P23|           64|
# |        C59|loyalty_score|       fruit_veg|       P23|           64|
# |       C132|loyalty_score|       fruit_veg|       P23|           64|
# |        C90|loyalty_score|       fruit_veg|       P23|           64|
# |       C126|loyalty_score|       fruit_veg|       P23|           64|
# |       C108|loyalty_score|       fruit_veg|       P23|           64|
# |        C92|loyalty_score|       fruit_veg|       P23|           64|
# |        C30|loyalty_score|       fruit_veg|       P23|           64|
# |        C57|loyalty_score|       fruit_veg|       P23|           64|
# |        C21|loyalty_score|       fruit_veg|       P23|           64|
# |        C36|loyalty_score|       fruit_veg|       P23|           64|
# |       C133|loyalty_score|       fruit_veg|       P23|           64|
# |       C124|loyalty_score|       fruit_veg|       P23|           64|
# |        C79|loyalty_score|       fruit_veg|       P23|           64|
# |        C48|loyalty_score|       fruit_veg|       P23|           64|
# |        C70|loyalty_score|       fruit_veg|       P23|           64|
# |       C117|loyalty_score|       fruit_veg|       P23|           64|
# |       C116|loyalty_score|       fruit_veg|       P23|           64|
# |        C10|loyalty_score|       fruit_veg|       P23|           64|
# |       C109|loyalty_score|       fruit_veg|       P23|           64|
# |       C102|loyalty_score|       fruit_veg|       P23|           64|
# |        C91|loyalty_score|       fruit_veg|       P23|           64|
# |         C1|loyalty_score|             bws|       P61|          155|
# |         C4|loyalty_score|             bws|       P61|          155|
# |       C104|loyalty_score|             bws|       P61|          155|
# |        C18|loyalty_score|             bws|       P61|          155|
# |       C105|loyalty_score|             bws|       P61|          155|
# |       C111|loyalty_score|             bws|       P61|          155|
# |        C20|loyalty_score|             bws|       P61|          155|
# |        C31|loyalty_score|             bws|       P61|          155|
# |        C49|loyalty_score|             bws|       P61|          155|
# |       C136|loyalty_score|             bws|       P61|          155|
# |        C98|loyalty_score|             bws|       P61|          155|
# |        C60|loyalty_score|             bws|       P61|          155|
# |       C110|loyalty_score|             bws|       P61|          155|
# |        C68|loyalty_score|             bws|       P61|          155|
# |        C55|loyalty_score|             bws|       P61|          155|
# |        C72|loyalty_score|             bws|       P61|          155|
# |       C101|loyalty_score|             bws|       P61|          155|
# |       C108|loyalty_score|             bws|       P61|          155|
# |        C10|loyalty_score|             bws|       P61|          155|
# |       C115|loyalty_score|             bws|       P61|          155|
# |        C32|loyalty_score|             bws|       P61|          155|
# |       C117|loyalty_score|             bws|       P61|          155|
# |        C26|loyalty_score|             bws|       P61|          155|
# |       C113|loyalty_score|             bws|       P61|          155|
# |        C45|loyalty_score|             bws|       P61|          155|
# |       C134|loyalty_score|             bws|       P61|          155|
# |        C95|loyalty_score|             bws|       P61|          155|
# |        C97|loyalty_score|             bws|       P61|          155|
# |       C106|loyalty_score|             bws|       P61|          155|
# |        C91|loyalty_score|             bws|       P61|          155|
# |        C38|loyalty_score|             bws|       P61|          155|
# |        C92|loyalty_score|             bws|       P61|          155|
# |        C23|loyalty_score|             bws|       P61|          155|
# |       C116|loyalty_score|             bws|       P61|          155|
# |        C67|loyalty_score|             bws|       P61|          155|
# |        C67|loyalty_score|       fruit_veg|       P33|           85|
# |        C28|loyalty_score|       fruit_veg|       P33|           85|
# |        C36|loyalty_score|       fruit_veg|       P33|           85|
# |        C45|loyalty_score|       fruit_veg|       P33|           85|
# |        C58|loyalty_score|       fruit_veg|       P33|           85|
# |       C131|loyalty_score|       fruit_veg|       P33|           85|
# |       C133|loyalty_score|       fruit_veg|       P33|           85|
# |       C126|loyalty_score|       fruit_veg|       P33|           85|
# |        C59|loyalty_score|       fruit_veg|       P33|           85|
# |        C30|loyalty_score|       fruit_veg|       P33|           85|
# |        C53|loyalty_score|       fruit_veg|       P33|           85|
# |       C132|loyalty_score|       fruit_veg|       P33|           85|
# |       C124|loyalty_score|       fruit_veg|       P33|           85|
# |        C55|loyalty_score|       fruit_veg|       P33|           85|
# |        C95|loyalty_score|       fruit_veg|       P33|           85|
# |        C32|loyalty_score|       fruit_veg|       P33|           85|
# |        C92|loyalty_score|       fruit_veg|       P33|           85|
# |        C99|loyalty_score|       fruit_veg|       P33|           85|
# |        C64|loyalty_score|       fruit_veg|       P33|           85|
# |       C107|loyalty_score|       fruit_veg|       P33|           85|
# |        C37|loyalty_score|       fruit_veg|       P33|           85|
# |        C70|loyalty_score|       fruit_veg|       P33|           85|
# |        C93|loyalty_score|       fruit_veg|       P33|           85|
# |        C48|loyalty_score|       fruit_veg|       P33|           85|
# |        C79|loyalty_score|       fruit_veg|       P33|           85|
# |       C108|loyalty_score|       fruit_veg|       P33|           85|
# |       C110|loyalty_score|       fruit_veg|       P33|           85|
# |         C2|loyalty_score|       fruit_veg|       P33|           85|
# |        C38|loyalty_score|       fruit_veg|       P33|           85|
# |        C42|loyalty_score|       fruit_veg|       P33|           85|
# |       C127|loyalty_score|       fruit_veg|       P33|           85|
# |       C120|loyalty_score|       fruit_veg|       P33|           85|
# |        C77|loyalty_score|       fruit_veg|       P33|           85|
# |        C52|loyalty_score|       fruit_veg|       P33|           85|
# |        C57|loyalty_score|       fruit_veg|       P33|           85|
# |       C103|loyalty_score|       fruit_veg|       P33|           85|
# |        C14|loyalty_score|       fruit_veg|       P33|           85|
# |        C78|loyalty_score|       fruit_veg|       P33|           85|
# |        C94|loyalty_score|       fruit_veg|       P33|           85|
# |       C128|loyalty_score|            food|       P44|           58|
# |         C8|loyalty_score|            food|       P44|           58|
# |       C123|loyalty_score|            food|       P44|           58|
# |       C106|loyalty_score|            food|       P44|           58|
# |        C73|loyalty_score|            food|       P44|           58|
# |       C105|loyalty_score|            food|       P44|           58|
# |        C12|loyalty_score|            food|       P44|           58|
# |        C99|loyalty_score|            food|       P44|           58|
# |       C110|loyalty_score|            food|       P44|           58|
# |         C6|loyalty_score|            food|       P44|           58|
# |         C3|loyalty_score|            food|       P44|           58|
# |        C66|loyalty_score|            food|       P44|           58|
# |       C102|loyalty_score|            food|       P44|           58|
# |        C62|loyalty_score|            food|       P44|           58|
# |        C28|loyalty_score|            food|       P44|           58|
# |        C47|loyalty_score|            food|       P44|           58|
# |       C125|loyalty_score|            food|       P44|           58|
# |        C57|loyalty_score|            food|       P44|           58|
# |        C11|loyalty_score|            food|       P44|           58|
# |        C65|loyalty_score|            food|       P44|           58|
# |        C96|loyalty_score|            food|       P44|           58|
# |        C17|loyalty_score|            food|       P44|           58|
# |        C93|loyalty_score|            food|       P44|           58|
# |        C67|loyalty_score|            food|       P44|           58|
# |        C81|loyalty_score|            food|       P44|           58|
# |       C107|loyalty_score|            food|       P44|           58|
# |        C35|loyalty_score|            food|       P44|           58|
# |        C80|loyalty_score|            food|       P44|           58|
# |        C45|loyalty_score|            food|       P44|           58|
# |        C53|loyalty_score|            food|       P44|           58|
# |       C108|loyalty_score|            food|       P44|           58|
# |        C32|loyalty_score|            food|       P44|           58|
# |        C34|loyalty_score|            food|       P44|           58|
# |        C91|loyalty_score|            food|       P44|           58|
# |        C63|loyalty_score|            food|       P44|           58|
# |         C5|loyalty_score|         clothes|       P15|           31|
# |        C97|loyalty_score|         clothes|       P15|           31|
# |        C21|loyalty_score|         clothes|       P15|           31|
# |        C25|loyalty_score|         clothes|       P15|           31|
# |        C27|loyalty_score|         clothes|       P15|           31|
# |        C35|loyalty_score|         clothes|       P15|           31|
# |        C18|loyalty_score|         clothes|       P15|           31|
# |        C83|loyalty_score|         clothes|       P15|           31|
# |       C117|loyalty_score|         clothes|       P15|           31|
# |       C128|loyalty_score|         clothes|       P15|           31|
# |       C137|loyalty_score|         clothes|       P15|           31|
# |        C71|loyalty_score|         clothes|       P15|           31|
# |        C34|loyalty_score|         clothes|       P15|           31|
# |       C134|loyalty_score|         clothes|       P15|           31|
# |        C58|loyalty_score|           house|       P11|           68|
# |        C13|loyalty_score|           house|       P11|           68|
# |        C41|loyalty_score|           house|       P11|           68|
# |        C86|loyalty_score|           house|       P11|           68|
# |        C75|loyalty_score|           house|       P11|           68|
# |        C61|loyalty_score|           house|       P11|           68|
# |        C89|loyalty_score|           house|       P11|           68|
# |        C51|loyalty_score|           house|       P11|           68|
# |       C102|loyalty_score|           house|       P11|           68|
# |       C127|loyalty_score|           house|       P11|           68|
# |        C96|loyalty_score|           house|       P11|           68|
# |       C129|loyalty_score|           house|       P11|           68|
# |        C43|loyalty_score|           house|       P11|           68|
# |        C84|loyalty_score|           house|       P11|           68|
# |       C125|loyalty_score|           house|       P11|           68|
# |        C65|loyalty_score|           house|       P11|           68|
# |        C94|loyalty_score|           house|       P11|           68|
# |        C46|loyalty_score|           house|       P11|           68|
# |        C17|loyalty_score|           house|       P11|           68|
# |        C83|loyalty_score|           house|       P11|           68|
# |        C77|loyalty_score|           house|       P11|           68|
# |       C117|loyalty_score|           house|       P11|           68|
# |       C137|loyalty_score|           house|       P11|           68|
# |         C1|loyalty_score|           house|       P11|           68|
# |         C7|loyalty_score|           house|       P11|           68|
# |       C132|loyalty_score|           house|       P11|           68|
# |       C130|loyalty_score|           house|       P11|           68|
# |        C79|loyalty_score|           house|       P11|           68|
# |        C93|loyalty_score|           house|       P11|           68|
# |        C17|loyalty_score|            food|       P47|           55|
# |       C105|loyalty_score|            food|       P47|           55|
# |       C112|loyalty_score|            food|       P47|           55|
# |        C12|loyalty_score|            food|       P47|           55|
# |         C3|loyalty_score|            food|       P47|           55|
# |       C100|loyalty_score|            food|       P47|           55|
# |        C28|loyalty_score|            food|       P47|           55|
# |        C15|loyalty_score|            food|       P47|           55|
# |        C25|loyalty_score|            food|       P47|           55|
# |        C11|loyalty_score|            food|       P47|           55|
# |        C66|loyalty_score|            food|       P47|           55|
# |        C53|loyalty_score|            food|       P47|           55|
# |         C6|loyalty_score|            food|       P47|           55|
# |        C62|loyalty_score|            food|       P47|           55|
# |        C80|loyalty_score|            food|       P47|           55|
# |        C67|loyalty_score|            food|       P47|           55|
# |        C65|loyalty_score|            food|       P47|           55|
# |        C73|loyalty_score|            food|       P47|           55|
# |        C50|loyalty_score|            food|       P47|           55|
# |       C101|loyalty_score|            food|       P47|           55|
# |        C95|loyalty_score|            food|       P47|           55|
# |       C135|loyalty_score|            food|       P47|           55|
# |        C91|loyalty_score|            food|       P47|           55|
# |        C34|loyalty_score|            food|       P47|           55|
# |        C99|loyalty_score|            food|       P47|           55|
# |       C125|loyalty_score|            food|       P47|           55|
# |        C16|loyalty_score|            food|       P47|           55|
# |        C54|loyalty_score|            food|       P47|           55|
# |        C78|loyalty_score|            food|       P47|           55|
# |        C57|loyalty_score|            food|       P47|           55|
# |       C110|loyalty_score|            food|       P47|           55|
# |        C96|loyalty_score|            food|       P47|           55|
# |       C109|loyalty_score|            food|       P47|           55|
# |        C30|loyalty_score|            food|       P47|           55|
# |        C61|loyalty_score|            food|       P47|           55|
# |         C8|loyalty_score|            food|       P42|           53|
# |        C83|loyalty_score|            food|       P42|           53|
# |       C103|loyalty_score|            food|       P42|           53|
# |        C66|loyalty_score|            food|       P42|           53|
# |        C15|loyalty_score|            food|       P42|           53|
# |        C99|loyalty_score|            food|       P42|           53|
# |        C12|loyalty_score|            food|       P42|           53|
# |        C49|loyalty_score|            food|       P42|           53|
# |       C102|loyalty_score|            food|       P42|           53|
# |       C125|loyalty_score|            food|       P42|           53|
# |        C55|loyalty_score|            food|       P42|           53|
# |        C80|loyalty_score|            food|       P42|           53|
# |        C41|loyalty_score|            food|       P42|           53|
# |       C106|loyalty_score|            food|       P42|           53|
# |        C10|loyalty_score|            food|       P42|           53|
# |       C101|loyalty_score|            food|       P42|           53|
# |       C109|loyalty_score|            food|       P42|           53|
# |        C74|loyalty_score|            food|       P42|           53|
# |       C110|loyalty_score|            food|       P42|           53|
# |        C67|loyalty_score|            food|       P42|           53|
# |        C34|loyalty_score|            food|       P42|           53|
# |        C62|loyalty_score|            food|       P42|           53|
# |        C28|loyalty_score|            food|       P42|           53|
# |        C63|loyalty_score|            food|       P42|           53|
# |        C78|loyalty_score|            food|       P42|           53|
# |        C48|loyalty_score|            food|       P42|           53|
# |        C81|loyalty_score|            food|       P42|           53|
# |        C57|loyalty_score|            food|       P42|           53|
# |       C113|loyalty_score|            food|       P42|           53|
# |        C64|loyalty_score|            food|       P42|           53|
# |        C35|loyalty_score|            food|       P42|           53|
# |       C112|loyalty_score|            food|       P42|           53|
# |       C108|loyalty_score|            food|       P42|           53|
# |        C11|loyalty_score|            food|       P42|           53|
# |       C135|loyalty_score|            food|       P42|           53|
# |        C59|loyalty_score|            food|       P42|           53|
# |       C120|loyalty_score|            food|       P42|           53|
# |       C117|loyalty_score|         clothes|       P21|           23|
# |        C78|loyalty_score|         clothes|       P21|           23|
# |       C105|loyalty_score|         clothes|       P21|           23|
# |        C25|loyalty_score|         clothes|       P21|           23|
# |        C21|loyalty_score|         clothes|       P21|           23|
# |        C18|loyalty_score|         clothes|       P21|           23|
# |        C13|loyalty_score|         clothes|       P21|           23|
# |        C71|loyalty_score|         clothes|       P21|           23|
# |        C67|loyalty_score|         clothes|       P21|           23|
# |        C27|loyalty_score|         clothes|       P21|           23|
# |        C35|loyalty_score|         clothes|       P21|           23|
# |       C128|loyalty_score|         clothes|       P21|           23|
# |        C65|loyalty_score|            food|       P53|           50|
# |        C83|loyalty_score|            food|       P53|           50|
# |        C97|loyalty_score|            food|       P53|           50|
# |       C125|loyalty_score|            food|       P53|           50|
# |        C12|loyalty_score|            food|       P53|           50|
# |       C107|loyalty_score|            food|       P53|           50|
# |        C34|loyalty_score|            food|       P53|           50|
# |        C25|loyalty_score|            food|       P53|           50|
# |        C10|loyalty_score|            food|       P53|           50|
# |        C80|loyalty_score|            food|       P53|           50|
# |       C112|loyalty_score|            food|       P53|           50|
# |        C44|loyalty_score|            food|       P53|           50|
# |        C53|loyalty_score|            food|       P53|           50|
# |         C3|loyalty_score|            food|       P53|           50|
# |        C48|loyalty_score|            food|       P53|           50|
# |         C7|loyalty_score|            food|       P53|           50|
# |        C81|loyalty_score|            food|       P53|           50|
# |       C103|loyalty_score|            food|       P53|           50|
# |         C6|loyalty_score|            food|       P53|           50|
# |        C62|loyalty_score|            food|       P53|           50|
# |        C55|loyalty_score|            food|       P53|           50|
# |       C120|loyalty_score|            food|       P53|           50|
# |         C8|loyalty_score|            food|       P53|           50|
# |        C17|loyalty_score|            food|       P53|           50|
# |        C99|loyalty_score|            food|       P53|           50|
# |        C66|loyalty_score|            food|       P53|           50|
# |        C57|loyalty_score|            food|       P53|           50|
# |       C110|loyalty_score|            food|       P53|           50|
# |        C35|loyalty_score|            food|       P53|           50|
# |        C67|loyalty_score|            food|       P53|           50|
# |       C128|loyalty_score|            food|       P53|           50|
# |        C52|loyalty_score|         clothes|       P14|           27|
# |         C5|loyalty_score|         clothes|       P14|           27|
# |        C25|loyalty_score|         clothes|       P14|           27|
# |       C134|loyalty_score|         clothes|       P14|           27|
# |        C63|loyalty_score|         clothes|       P14|           27|
# |        C71|loyalty_score|         clothes|       P14|           27|
# |        C34|loyalty_score|         clothes|       P14|           27|
# |       C117|loyalty_score|         clothes|       P14|           27|
# |        C13|loyalty_score|         clothes|       P14|           27|
# |        C21|loyalty_score|         clothes|       P14|           27|
# |        C56|loyalty_score|           house|       P07|           70|
# |       C119|loyalty_score|           house|       P07|           70|
# |        C55|loyalty_score|           house|       P07|           70|
# |        C58|loyalty_score|           house|       P07|           70|
# |        C83|loyalty_score|           house|       P07|           70|
# |        C48|loyalty_score|           house|       P07|           70|
# |        C75|loyalty_score|           house|       P07|           70|
# |        C41|loyalty_score|           house|       P07|           70|
# |        C14|loyalty_score|           house|       P07|           70|
# |         C7|loyalty_score|           house|       P07|           70|
# |       C127|loyalty_score|           house|       P07|           70|
# |       C134|loyalty_score|           house|       P07|           70|
# |         C1|loyalty_score|           house|       P07|           70|
# |        C96|loyalty_score|           house|       P07|           70|
# |       C100|loyalty_score|           house|       P07|           70|
# |        C50|loyalty_score|           house|       P07|           70|
# |       C125|loyalty_score|           house|       P07|           70|
# |        C17|loyalty_score|           house|       P07|           70|
# |        C72|loyalty_score|           house|       P07|           70|
# |        C66|loyalty_score|           house|       P07|           70|
# |        C86|loyalty_score|           house|       P07|           70|
# |       C118|loyalty_score|           house|       P07|           70|
# |       C109|loyalty_score|           house|       P07|           70|
# |        C85|loyalty_score|           house|       P07|           70|
# |        C69|loyalty_score|           house|       P07|           70|
# |       C117|loyalty_score|           house|       P07|           70|
# |        C82|loyalty_score|           house|       P07|           70|
# |        C13|loyalty_score|           house|       P07|           70|
# |        C43|loyalty_score|           house|       P07|           70|
# |        C19|loyalty_score|           house|       P07|           70|
# |        C94|loyalty_score|           house|       P07|           70|
# |        C65|loyalty_score|           house|       P07|           70|
# |        C71|loyalty_score|           house|       P07|           70|
# |        C74|loyalty_score|           house|       P07|           70|
# |        C89|loyalty_score|           house|       P07|           70|
# |       C129|loyalty_score|           house|       P07|           70|
# |        C77|loyalty_score|           house|       P07|           70|
# |        C39|loyalty_score|           house|       P07|           70|
# |        C48|loyalty_score|       fruit_veg|       P32|           74|
# |       C134|loyalty_score|       fruit_veg|       P32|           74|
# |        C90|loyalty_score|       fruit_veg|       P32|           74|
# |        C79|loyalty_score|       fruit_veg|       P32|           74|
# |       C126|loyalty_score|       fruit_veg|       P32|           74|
# |        C32|loyalty_score|       fruit_veg|       P32|           74|
# |        C59|loyalty_score|       fruit_veg|       P32|           74|
# |        C69|loyalty_score|       fruit_veg|       P32|           74|
# |        C53|loyalty_score|       fruit_veg|       P32|           74|
# |        C74|loyalty_score|       fruit_veg|       P32|           74|
# |        C78|loyalty_score|       fruit_veg|       P32|           74|
# |        C94|loyalty_score|       fruit_veg|       P32|           74|
# |       C107|loyalty_score|       fruit_veg|       P32|           74|
# |        C92|loyalty_score|       fruit_veg|       P32|           74|
# |        C57|loyalty_score|       fruit_veg|       P32|           74|
# |        C14|loyalty_score|       fruit_veg|       P32|           74|
# |       C127|loyalty_score|       fruit_veg|       P32|           74|
# |        C64|loyalty_score|       fruit_veg|       P32|           74|
# |        C70|loyalty_score|       fruit_veg|       P32|           74|
# |        C56|loyalty_score|       fruit_veg|       P32|           74|
# |        C65|loyalty_score|       fruit_veg|       P32|           74|
# |        C21|loyalty_score|       fruit_veg|       P32|           74|
# |        C39|loyalty_score|       fruit_veg|       P32|           74|
# |        C44|loyalty_score|       fruit_veg|       P32|           74|
# |       C116|loyalty_score|       fruit_veg|       P32|           74|
# |       C120|loyalty_score|       fruit_veg|       P32|           74|
# |        C23|loyalty_score|       fruit_veg|       P32|           74|
# |        C72|loyalty_score|       fruit_veg|       P32|           74|
# |       C117|loyalty_score|       fruit_veg|       P32|           74|
# |        C28|loyalty_score|       fruit_veg|       P32|           74|
# |       C104|loyalty_score|       fruit_veg|       P32|           74|
# |        C55|loyalty_score|       fruit_veg|       P32|           74|
# |       C121|loyalty_score|       fruit_veg|       P32|           74|
# |        C99|loyalty_score|       fruit_veg|       P32|           74|
# |        C37|loyalty_score|       fruit_veg|       P32|           74|
# |        C29|loyalty_score|       fruit_veg|       P32|           74|
# |       C109|loyalty_score|       fruit_veg|       P32|           74|
# |       C110|loyalty_score|       fruit_veg|       P32|           74|
# |        C54|loyalty_score|       fruit_veg|       P32|           74|
# |       C133|loyalty_score|       fruit_veg|       P32|           74|
# |        C52|loyalty_score|       fruit_veg|       P32|           74|
# |        C95|loyalty_score|       fruit_veg|       P32|           74|
# |       C132|loyalty_score|       fruit_veg|       P32|           74|
# |        C67|loyalty_score|       fruit_veg|       P32|           74|
# |        C88|loyalty_score|       fruit_veg|       P32|           74|
# |        C93|loyalty_score|       fruit_veg|       P32|           74|
# |        C68|loyalty_score|             bws|       P63|          156|
# |       C104|loyalty_score|             bws|       P63|          156|
# |        C31|loyalty_score|             bws|       P63|          156|
# |       C111|loyalty_score|             bws|       P63|          156|
# |       C136|loyalty_score|             bws|       P63|          156|
# |        C20|loyalty_score|             bws|       P63|          156|
# |        C49|loyalty_score|             bws|       P63|          156|
# |         C1|loyalty_score|             bws|       P63|          156|
# |        C61|loyalty_score|             bws|       P63|          156|
# |        C98|loyalty_score|             bws|       P63|          156|
# |       C113|loyalty_score|             bws|       P63|          156|
# |        C60|loyalty_score|             bws|       P63|          156|
# |       C101|loyalty_score|             bws|       P63|          156|
# |        C92|loyalty_score|             bws|       P63|          156|
# |       C110|loyalty_score|             bws|       P63|          156|
# |       C117|loyalty_score|             bws|       P63|          156|
# |       C108|loyalty_score|             bws|       P63|          156|
# |       C120|loyalty_score|             bws|       P63|          156|
# |       C115|loyalty_score|             bws|       P63|          156|
# |        C18|loyalty_score|             bws|       P63|          156|
# |        C26|loyalty_score|             bws|       P63|          156|
# |        C97|loyalty_score|             bws|       P63|          156|
# |       C116|loyalty_score|             bws|       P63|          156|
# |        C45|loyalty_score|             bws|       P63|          156|
# |         C4|loyalty_score|             bws|       P63|          156|
# |        C38|loyalty_score|             bws|       P63|          156|
# |        C51|loyalty_score|             bws|       P63|          156|
# |       C109|loyalty_score|             bws|       P63|          156|
# |        C55|loyalty_score|             bws|       P63|          156|
# |        C95|loyalty_score|             bws|       P63|          156|
# |       C134|loyalty_score|             bws|       P63|          156|
# |        C91|loyalty_score|             bws|       P63|          156|
# |        C67|loyalty_score|             bws|       P63|          156|
# |        C32|loyalty_score|             bws|       P63|          156|
# |       C105|loyalty_score|             bws|       P63|          156|
# |        C41|loyalty_score|           house|       P04|           57|
# |        C56|loyalty_score|           house|       P04|           57|
# |        C13|loyalty_score|           house|       P04|           57|
# |        C89|loyalty_score|           house|       P04|           57|
# |       C129|loyalty_score|           house|       P04|           57|
# |        C43|loyalty_score|           house|       P04|           57|
# |        C72|loyalty_score|           house|       P04|           57|
# |       C125|loyalty_score|           house|       P04|           57|
# |        C61|loyalty_score|           house|       P04|           57|
# |        C48|loyalty_score|           house|       P04|           57|
# |        C77|loyalty_score|           house|       P04|           57|
# |        C50|loyalty_score|           house|       P04|           57|
# |        C94|loyalty_score|           house|       P04|           57|
# |       C134|loyalty_score|           house|       P04|           57|
# |        C65|loyalty_score|           house|       P04|           57|
# |        C17|loyalty_score|           house|       P04|           57|
# |       C130|loyalty_score|           house|       P04|           57|
# |         C1|loyalty_score|           house|       P04|           57|
# |        C55|loyalty_score|           house|       P04|           57|
# |       C115|loyalty_score|           house|       P04|           57|
# |        C86|loyalty_score|           house|       P04|           57|
# |       C100|loyalty_score|           house|       P04|           57|
# |        C66|loyalty_score|           house|       P04|           57|
# |       C117|loyalty_score|           house|       P04|           57|
# |        C79|loyalty_score|           house|       P04|           57|
# |       C106|loyalty_score|           house|       P04|           57|
# |       C133|loyalty_score|       fruit_veg|       P27|           73|
# |        C21|loyalty_score|       fruit_veg|       P27|           73|
# |        C48|loyalty_score|       fruit_veg|       P27|           73|
# |        C28|loyalty_score|       fruit_veg|       P27|           73|
# |        C93|loyalty_score|       fruit_veg|       P27|           73|
# |       C126|loyalty_score|       fruit_veg|       P27|           73|
# |        C92|loyalty_score|       fruit_veg|       P27|           73|
# |        C55|loyalty_score|       fruit_veg|       P27|           73|
# |        C57|loyalty_score|       fruit_veg|       P27|           73|
# |        C99|loyalty_score|       fruit_veg|       P27|           73|
# |       C107|loyalty_score|       fruit_veg|       P27|           73|
# |        C32|loyalty_score|       fruit_veg|       P27|           73|
# |        C27|loyalty_score|       fruit_veg|       P27|           73|
# |        C64|loyalty_score|       fruit_veg|       P27|           73|
# |        C37|loyalty_score|       fruit_veg|       P27|           73|
# |        C59|loyalty_score|       fruit_veg|       P27|           73|
# |       C127|loyalty_score|       fruit_veg|       P27|           73|
# |        C70|loyalty_score|       fruit_veg|       P27|           73|
# |        C79|loyalty_score|       fruit_veg|       P27|           73|
# |       C102|loyalty_score|       fruit_veg|       P27|           73|
# |       C131|loyalty_score|       fruit_veg|       P27|           73|
# |         C2|loyalty_score|       fruit_veg|       P27|           73|
# |       C120|loyalty_score|       fruit_veg|       P27|           73|
# |        C38|loyalty_score|       fruit_veg|       P27|           73|
# |         C7|loyalty_score|       fruit_veg|       P27|           73|
# |       C136|loyalty_score|       fruit_veg|       P27|           73|
# +-----------+-------------+----------------+----------+-------------+
# only showing top 600 rows
